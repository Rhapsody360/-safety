# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("heart_attack_prediction_dataset.csv")
data.info
# Out:
# <bound method DataFrame.info of      Patient ID  Age     Sex  Cholesterol  sys0  dys0  sys1  dys1  sys2  dys2  \
# 0       BMW7812   67    Male          208   158    88   140   112   135    90
# 1       CZE1114   21    Male          389   165    93   130   112   133   114
# 2       BNI9906   21  Female          324   174    99   134   115   133   112
# 3       JLN3497   84    Male          383   163   100   132    92   140    98
# 4       GFO8847   66    Male          318    91    88   140    93   134   116
# ...         ...  ...     ...          ...   ...   ...   ...   ...   ...   ...
# 8758    MSV9918   60    Male          121    94    76   135   101   130    98
# 8759    QSV6764   28  Female          120   157   102   135    92   130   100
# 8760    XKA5925   47    Male          250   161    75   130   120   130    95
# 8761    EPE6801   36    Male          178   119    67   139    94   138   106
# 8762    ZWN9666   25  Female          356   138    67   139   119   138   108
#
#       ...  Obesity  Alcohol Consumption       Diet  Previous Heart Problems  \
# 0     ...        0                    0    Average                        0
# 1     ...        1                    1  Unhealthy                        1
# 2     ...        0                    0    Healthy                        1
# 3     ...        0                    1    Average                        1
# 4     ...        1                    0  Unhealthy                        1
# ...   ...      ...                  ...        ...                      ...
# 8758  ...        0                    1    Healthy                        1
# 8759  ...        1                    0    Healthy                        0
# 8760  ...        1                    1    Average                        1
# 8761  ...        0                    0  Unhealthy                        1
# 8762  ...        0                    1    Healthy                        0
#
#       Medication Use  Stress Level        BMI  Triglycerides  \
# 0                  0             9  31.251233            286
# 1                  0             1  27.194973            235
# 2                  1             9  28.176571            587
# 3                  0             9  36.464704            378
# 4                  0             6  21.809144            231
# ...              ...           ...        ...            ...
# 8758               1             8  19.655895             67
# 8759               0             8  23.993866            617
# 8760               0             5  35.406146            527
# 8761               1             5  27.294020            114
# 8762               0             8  32.914151            180
#
#      Physical Activity Days Per Week  Sleep Hours Per Day
# 0                                  0                    6
# 1                                  1                    7
# 2                                  4                    4
# 3                                  3                    4
# 4                                  1                    5
# ...                              ...                  ...
# 8758                               7                    7
# 8759                               4                    9
# 8760                               4                    4
# 8761                               2                    8
# 8762                               7                    4
#
# [8763 rows x 26 columns]>

# %%
data.head()
# Out:
#   Patient ID  Age     Sex  Cholesterol  sys0  dys0  sys1  dys1  sys2  dys2  \
# 0    BMW7812   67    Male          208   158    88   140   112   135    90
# 1    CZE1114   21    Male          389   165    93   130   112   133   114
# 2    BNI9906   21  Female          324   174    99   134   115   133   112
# 3    JLN3497   84    Male          383   163   100   132    92   140    98
# 4    GFO8847   66    Male          318    91    88   140    93   134   116
#
#    ...  Obesity  Alcohol Consumption       Diet  Previous Heart Problems  \
# 0  ...        0                    0    Average                        0
# 1  ...        1                    1  Unhealthy                        1
# 2  ...        0                    0    Healthy                        1
# 3  ...        0                    1    Average                        1
# 4  ...        1                    0  Unhealthy                        1
#
#    Medication Use  Stress Level        BMI  Triglycerides  \
# 0               0             9  31.251233            286
# 1               0             1  27.194973            235
# 2               1             9  28.176571            587
# 3               0             9  36.464704            378
# 4               0             6  21.809144            231
#
#   Physical Activity Days Per Week  Sleep Hours Per Day
# 0                               0                    6
# 1                               1                    7
# 2                               4                    4
# 3                               3                    4
# 4                               1                    5
#
# [5 rows x 26 columns]

# %%
data.describe()
# Out:
#                Age  Cholesterol         sys0         dys0         sys1  \
# count  8763.000000  8763.000000  8763.000000  8763.000000  8763.000000
# mean     53.707977   259.877211   135.075659    85.156111   134.978204
# std      21.249509    80.863276    26.349976    14.676565     3.161643
# min      18.000000   120.000000    90.000000    60.000000   130.000000
# 25%      35.000000   192.000000   112.000000    72.000000   132.000000
# 50%      54.000000   259.000000   135.000000    85.000000   135.000000
# 75%      72.000000   330.000000   158.000000    98.000000   138.000000
# max      90.000000   400.000000   180.000000   110.000000   140.000000
#
#               dys1         sys2         dys2         sys3         dys3  ...  \
# count  8763.000000  8763.000000  8763.000000  8763.000000  8763.000000  ...
# mean    104.581422   134.980486   104.478033   135.013694   104.619879  ...
# std       9.236035     3.168725     9.255698     3.153212     9.237964  ...
# min      89.000000   130.000000    89.000000   130.000000    89.000000  ...
# 25%      96.000000   132.000000    96.000000   132.000000    97.000000  ...
# 50%     105.000000   135.000000   104.000000   135.000000   105.000000  ...
# 75%     113.000000   138.000000   113.000000   138.000000   113.000000  ...
# max     120.000000   140.000000   120.000000   140.000000   120.000000  ...
#
#            Smoking      Obesity  Alcohol Consumption  Previous Heart Problems  \
# count  8763.000000  8763.000000          8763.000000              8763.000000
# mean      0.896839     0.501426             0.598083                 0.495835
# std       0.304186     0.500026             0.490313                 0.500011
# min       0.000000     0.000000             0.000000                 0.000000
# 25%       1.000000     0.000000             0.000000                 0.000000
# 50%       1.000000     1.000000             1.000000                 0.000000
# 75%       1.000000     1.000000             1.000000                 1.000000
# max       1.000000     1.000000             1.000000                 1.000000
#
#        Medication Use  Stress Level          BMI  Triglycerides  \
# count     8763.000000   8763.000000  8763.000000    8763.000000
# mean         0.498345      5.469702    28.891446     417.677051
# std          0.500026      2.859622     6.319181     223.748137
# min          0.000000      1.000000    18.002337      30.000000
# 25%          0.000000      3.000000    23.422985     225.500000
# 50%          0.000000      5.000000    28.768999     417.000000
# 75%          1.000000      8.000000    34.324594     612.000000
# max          1.000000     10.000000    39.997211     800.000000
#
#        Physical Activity Days Per Week  Sleep Hours Per Day
# count                      8763.000000          8763.000000
# mean                          3.489672             7.023508
# std                           2.282687             1.988473
# min                           0.000000             4.000000
# 25%                           2.000000             5.000000
# 50%                           3.000000             7.000000
# 75%                           5.000000             9.000000
# max                           7.000000            10.000000
#
# [8 rows x 23 columns]

# %%
data.columns
# Out:
# Index(['Patient ID', 'Age', 'Sex', 'Cholesterol', 'sys0', 'dys0', 'sys1',
#        'dys1', 'sys2', 'dys2', 'sys3', 'dys3', 'Heart Rate', 'Diabetes',
#        'Family History', 'Smoking', 'Obesity', 'Alcohol Consumption', 'Diet',
#        'Previous Heart Problems', 'Medication Use', 'Stress Level', 'BMI',
#        'Triglycerides', 'Physical Activity Days Per Week',
#        'Sleep Hours Per Day'],
#       dtype='object')

# %%
# dataset 0
ctg_data = data[['Sex','Diet']]
#data set 1
#ctg_data = data[['Sex','Diet','Continent','Country','Hemisphere']]
# data = pd.get_dummies(data, columns = ['Sex'])

# %%
sex_map = {'Male':1,'Female':2}
data['Sex']=data['Sex'].map(sex_map)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Patient ID                       8763 non-null   object
#  1   Age                              8763 non-null   int64
#  2   Sex                              8763 non-null   int64
#  3   Cholesterol                      8763 non-null   int64
#  4   sys0                             8763 non-null   int64
#  5   dys0                             8763 non-null   int64
#  6   sys1                             8763 non-null   int64
#  7   dys1                             8763 non-null   int64
#  8   sys2                             8763 non-null   int64
#  9   dys2                             8763 non-null   int64
#  10  sys3                             8763 non-null   int64
#  11  dys3                             8763 non-null   int64
#  12  Heart Rate                       8763 non-null   int64
#  13  Diabetes                         8763 non-null   int64
#  14  Family History                   8763 non-null   int64
#  15  Smoking                          8763 non-null   int64
#  16  Obesity                          8763 non-null   int64
#  17  Alcohol Consumption              8763 non-null   int64
#  18  Diet                             8763 non-null   object
#  19  Previous Heart Problems          8763 non-null   int64
#  20  Medication Use                   8763 non-null   int64
#  21  Stress Level                     8763 non-null   int64
#  22  BMI                              8763 non-null   float64
#  23  Triglycerides                    8763 non-null   int64
#  24  Physical Activity Days Per Week  8763 non-null   int64
#  25  Sleep Hours Per Day              8763 non-null   int64
# dtypes: float64(1), int64(23), object(2)
# memory usage: 1.7+ MB

# %%
# data['BP_Systolic'] = data['Blood Pressure'].apply(lambda x: x.split('/')[0])
# data['BP_Diastolic'] = data['Blood Pressure'].apply(lambda x: x.split('/')[1])

# %%
ordinal_map = {'Healthy':3,'Average':2,'Unhealthy':1}
data['Diet'] = data['Diet'].map(ordinal_map)

# %%
# cat_columns = ['Sex_Female','Sex_Male','BP_Systolic','BP_Diastolic']
# cat_columns = ['Sex_Female','Sex_Male']

#data[cat_columns] = data[cat_columns].astype(int)

# %%
# plt.figure(figsize=(8, 7))
# for i in ctg_data.columns:
#     ctg_num = ctg_data[i].value_counts()
#     chart = sns.barplot(x = ctg_num.index, y = ctg_num)
#     for p in chart.patches:
#         chart.annotate(format(p.get_height(), '.0f'), 
#                      (p.get_x() + p.get_width() / 2., p.get_height()), 
#                      ha = 'center', va = 'center', 
#                      xytext = (0, 10), 
#                      textcoords = 'offset points',
#                      fontsize=10)
        
#     chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
#     plt.show()

# %%
data.head()
# Out:
#   Patient ID  Age  Sex  Cholesterol  sys0  dys0  sys1  dys1  sys2  dys2  ...  \
# 0    BMW7812   67    1          208   158    88   140   112   135    90  ...
# 1    CZE1114   21    1          389   165    93   130   112   133   114  ...
# 2    BNI9906   21    2          324   174    99   134   115   133   112  ...
# 3    JLN3497   84    1          383   163   100   132    92   140    98  ...
# 4    GFO8847   66    1          318    91    88   140    93   134   116  ...
#
#    Obesity  Alcohol Consumption  Diet  Previous Heart Problems  \
# 0        0                    0     2                        0
# 1        1                    1     1                        1
# 2        0                    0     3                        1
# 3        0                    1     2                        1
# 4        1                    0     1                        1
#
#    Medication Use  Stress Level        BMI  Triglycerides  \
# 0               0             9  31.251233            286
# 1               0             1  27.194973            235
# 2               1             9  28.176571            587
# 3               0             9  36.464704            378
# 4               0             6  21.809144            231
#
#    Physical Activity Days Per Week  Sleep Hours Per Day
# 0                                0                    6
# 1                                1                    7
# 2                                4                    4
# 3                                3                    4
# 4                                1                    5
#
# [5 rows x 26 columns]

# %%
plt.figure(figsize = (25,15))
sns.heatmap(data[['Age', 'Cholesterol', 'sys0', 'dys0', 'sys1',
       'dys1', 'sys2', 'dys2', 'sys3', 'dys3', 'Heart Rate', 'Diabetes',
       'Family History', 'Smoking', 'Obesity', 'Alcohol Consumption', 'Diet',
       'Previous Heart Problems', 'Medication Use', 'Stress Level', 'BMI',
       'Triglycerides', 'Physical Activity Days Per Week',
       'Sleep Hours Per Day', 'Sex']].corr(), cmap="YlGnBu",
            annot=True)
# Out:
# <Axes: >

# %%
#data = pd.get_dummies(data, columns = ['Country','Continent','Hemisphere'])

# %%
data.dtypes
# Out:
# Patient ID                          object
# Age                                  int64
# Sex                                  int64
# Cholesterol                          int64
# sys0                                 int64
# dys0                                 int64
# sys1                                 int64
# dys1                                 int64
# sys2                                 int64
# dys2                                 int64
# sys3                                 int64
# dys3                                 int64
# Heart Rate                           int64
# Diabetes                             int64
# Family History                       int64
# Smoking                              int64
# Obesity                              int64
# Alcohol Consumption                  int64
# Diet                                 int64
# Previous Heart Problems              int64
# Medication Use                       int64
# Stress Level                         int64
# BMI                                float64
# Triglycerides                        int64
# Physical Activity Days Per Week      int64
# Sleep Hours Per Day                  int64
# dtype: object

# %%
data.columns
# Out:
# Index(['Patient ID', 'Age', 'Sex', 'Cholesterol', 'sys0', 'dys0', 'sys1',
#        'dys1', 'sys2', 'dys2', 'sys3', 'dys3', 'Heart Rate', 'Diabetes',
#        'Family History', 'Smoking', 'Obesity', 'Alcohol Consumption', 'Diet',
#        'Previous Heart Problems', 'Medication Use', 'Stress Level', 'BMI',
#        'Triglycerides', 'Physical Activity Days Per Week',
#        'Sleep Hours Per Day'],
#       dtype='object')

# %%
X = data [['Age', 'Cholesterol', 'sys0', 'dys0', 'sys1', 'dys1',
       'sys2', 'dys2', 'sys3', 'dys3', 'Heart Rate', 'Diabetes',
       'Family History', 'Smoking', 'Obesity', 'Alcohol Consumption', 'Diet',
       'Previous Heart Problems', 'Medication Use', 'Stress Level', 'BMI',
       'Triglycerides', 'Physical Activity Days Per Week',
       'Sleep Hours Per Day', 'Sex']]
#Y = data [['Heart Attack Risk']]
X=X.dropna(how='any')
X.head(20)
# Out:
#     Age  Cholesterol  sys0  dys0  sys1  dys1  sys2  dys2  sys3  dys3  ...  \
# 0    67          208   158    88   140   112   135    90   131    93  ...
# 1    21          389   165    93   130   112   133   114   133   115  ...
# 2    21          324   174    99   134   115   133   112   135   102  ...
# 3    84          383   163   100   132    92   140    98   133    96  ...
# 4    66          318    91    88   140    93   134   116   131   104  ...
# 5    54          297   172    86   139   119   130   115   139   103  ...
# 6    90          358   102    73   130    97   132    97   136    92  ...
# 7    84          220   131    68   135   120   131   117   130    98  ...
# 8    20          145   144   105   133    90   135   107   138   100  ...
# 9    43          248   160    70   131   112   132    93   138   117  ...
# 10   73          373   107    69   136   118   135    99   135   112  ...
# 11   71          374   158    71   134   106   131   109   133   106  ...
# 12   77          228   101    72   138   101   139   116   130    93  ...
# 13   60          259   169    72   136   118   140   100   140   120  ...
# 14   88          297   112    81   140    98   131   113   131   108  ...
# 15   73          122   114    88   140   111   133   117   131   112  ...
# 16   69          379   173    75   136    91   130   103   131    89  ...
# 17   38          166   120    74   140   105   134    91   137    96  ...
# 18   50          303   120   100   135    90   130    94   135    91  ...
# 19   60          145   160    98   136   109   130   103   139    93  ...
#
#     Alcohol Consumption  Diet  Previous Heart Problems  Medication Use  \
# 0                     0     2                        0               0
# 1                     1     1                        1               0
# 2                     0     3                        1               1
# 3                     1     2                        1               0
# 4                     0     1                        1               0
# 5                     1     1                        1               1
# 6                     1     3                        0               0
# 7                     1     2                        0               1
# 8                     0     2                        0               0
# 9                     1     1                        0               0
# 10                    1     2                        1               1
# 11                    1     2                        0               0
# 12                    1     1                        0               0
# 13                    1     3                        1               1
# 14                    1     1                        0               1
# 15                    1     2                        0               0
# 16                    1     2                        1               0
# 17                    0     3                        0               1
# 18                    1     2                        1               1
# 19                    1     3                        1               0
#
#     Stress Level        BMI  Triglycerides  Physical Activity Days Per Week  \
# 0              9  31.251233            286                                0
# 1              1  27.194973            235                                1
# 2              9  28.176571            587                                4
# 3              9  36.464704            378                                3
# 4              6  21.809144            231                                1
# 5              2  20.146839            795                                5
# 6              7  28.885811            284                                4
# 7              4  22.221862            370                                6
# 8              5  35.809901            790                                7
# 9              4  22.558917            232                                7
# 10             8  22.867911            469                                0
# 11             4  32.485345            523                                4
# 12             9  35.102236            590                                7
# 13             1  25.564897            506                                1
# 14             2  25.491741            635                                3
# 15             5  36.524395            773                                5
# 16             5  28.332747             68                                3
# 17             9  29.517388            402                                0
# 18             1  25.964351            517                                1
# 19             8  29.162319            247                                7
#
#     Sleep Hours Per Day  Sex
# 0                     6    1
# 1                     7    1
# 2                     4    2
# 3                     4    1
# 4                     5    1
# 5                    10    2
# 6                    10    1
# 7                     7    1
# 8                     4    1
# 9                     7    2
# 10                    4    2
# 11                    8    1
# 12                    6    1
# 13                    4    1
# 14                    6    1
# 15                    8    1
# 16                    6    1
# 17                    6    1
# 18                    5    2
# 19                    7    1
#
# [20 rows x 25 columns]

# %%
from sklearn.cluster import KMeans
import numpy as np
kmeans = KMeans(n_clusters=2, random_state=0, n_init="auto", max_iter=8800).fit(X)
kmeans.labels_
# kmeans.predict([[0, 0], [12, 3]])
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[5.38986038e+01 2.59540398e+02 1.35189517e+02 8.50723278e+01
#   1.34995193e+02 1.04541085e+02 1.34931334e+02 1.04463722e+02
#   1.35049897e+02 1.04549096e+02 7.52748913e+01 6.54612039e-01
#   4.92332341e-01 9.02494850e-01 5.04921035e-01 5.98306249e-01
#   2.00389105e+00 4.89814603e-01 4.90501259e-01 5.47150378e+00
#   2.88681588e+01 6.11858091e+02 3.48477913e+00 6.97390707e+00
#   1.29983978e+00]
#  [5.35184342e+01 2.60212107e+02 1.34962449e+02 8.52394174e+01
#   1.34961311e+02 1.04621529e+02 1.35029358e+02 1.04492262e+02
#   1.34977697e+02 1.04690259e+02 7.47699135e+01 6.49977242e-01
#   4.93627674e-01 8.91215294e-01 4.97951752e-01 5.97860719e-01
#   2.01183432e+00 5.01820665e-01 5.06144743e-01 5.46791079e+00
#   2.89146004e+01 2.24600819e+02 3.49453801e+00 7.07282658e+00
#   1.30541648e+00]]

# %%
# label = kmeans.fit_predict(X)
# #Getting unique labels
# u_labels = np.unique(label)
# #plotting the results:
# for i in u_labels:
#     plt.scatter(X[label == i , 0] , X[label == i , 1] , label = i)
# plt.legend()
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File d:\compilers\py\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File d:\compilers\py\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File d:\compilers\py\Lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(array([False, False, False, ..., False, False, False]), 0)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[120], line 6
#       4 #plotting the results:
#       5 for i in u_labels:
# ----> 6     plt.scatter(X[label == i , 0] , X[label == i , 1] , label = i)
#       7 plt.legend()
#       8 plt.show()
#
# File d:\compilers\py\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File d:\compilers\py\Lib\site-packages\pandas\core\indexes\base.py:3809, in Index.get_loc(self, key, method, tolerance)
#    3804         raise KeyError(key) from err
#    3805     except TypeError:
#    3806         # If we have a listlike key, _check_indexing_error will raise
#    3807         #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808         #  the TypeError.
# -> 3809         self._check_indexing_error(key)
#    3810         raise
#    3812 # GH#42269
#
# File d:\compilers\py\Lib\site-packages\pandas\core\indexes\base.py:5925, in Index._check_indexing_error(self, key)
#    5921 def _check_indexing_error(self, key):
#    5922     if not is_scalar(key):
#    5923         # if key is not a scalar, directly raise an error (the code below
#    5924         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5925         raise InvalidIndexError(key)
#
# InvalidIndexError: (array([False, False, False, ..., False, False, False]), 0)
